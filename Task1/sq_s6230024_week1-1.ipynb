# %% [markdown]
# Answers for Week 1
#
# * Name: Grace Ketchum
# * Username: gbketchum
# * Student s-number: S6230024
# * Group: AS1

# %%
x=22/7

# %% [markdown]
# $$y=\frac{sin(x)}{x}$$

# %%
pi = 22/7 # Processed on Jupyter Hub

# %%
sixfactorial=6
sixfactorial*=5
sixfactorial*=4
sixfactorial*=3
sixfactorial*=2
print(sixfactorial)
# Out:
# 720

# %%
from scipy.constants import h
f=2.42e28
energy=h*f
print(energy)
# Out:
# 1.6035089763e-05

# %%
from scipy.constants import G
mass_moon=7.342e22
mass_earth=5.9722e24
r=385000.6e3
force=G*mass_moon*mass_earth/(r**2)
print(force)
# Out:
# 1.974384051807571e+20

# %% [markdown]
# ![ss1.png](attachment:ss1.png)

# %% [markdown]
# ![ss2.png](attachment:ss2.png)

# %% [markdown]
# ![ss3.png](attachment:ss3.png)

# %% [markdown]
# 1.15
# 1)It shows the absolute path
# /Users/users/gbketchum/Downloads
# 2). is the currenty directory and .. is the parent directory

# %% [markdown]
# 1.16 The command is cd ~/directory name

# %% [markdown]
# 1.19 1. The first command reveals all files with the numbers 0 to 9 in the title, as well as ending with either a c or an o. 2. It creates a list of variables (here either c or o) 3. This command means there must be .co at the end
